# %%
#pip install odo

# %%
#Import dependencies
import pandas as pd
import numpy as np
import json
from sqlalchemy import create_engine
import psycopg2 as ps
import pymongo
from pymongo import MongoClient

# %%
# Read the csv
movie_data = pd.read_csv("./Resources/tmdb_5000_movies.csv")
movie_data.head(2)
credits_data = pd.read_csv("./Resources/tmdb_5000_credits.csv")
credits_data.head(2)
movie_data.count()
credits_data.count()
# Out:
# movie_id    4803
# title       4803
# cast        4803
# crew        4803
# dtype: int64

# %%
movie_data1 = pd.DataFrame(movie_data)
movie_data1
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5     258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6     260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7     280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8     250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9     250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10    270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11    200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12    200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...

# %%
credits_data1 = pd.DataFrame(credits_data)
credits_data1.count()
# Out:
# movie_id    4803
# title       4803
# cast        4803
# crew        4803
# dtype: int64

# %%
merge_df = pd.merge(left=movie_data1, right=credits_data1, how="left")
merge_df.head(46)
# Out:
#        budget                                             genres  \
# 0   237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1   300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2   245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3   250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4   260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5   258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6   260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7   280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8   250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9   250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10  270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11  200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12  200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...

# %%
merge_df_1 = merge_df[merge_df.production_countries != '[]']
merge_df_1.count()
# Out:
# budget                  4635
# genres                  4635
# homepage                1677
# id                      4635
# keywords                4635
# original_language       4635
# original_title          4635
# overview                4633
# popularity              4635
# production_companies    4635
# production_countries    4635
# release_date            4635
# revenue                 4635
# runtime                 4633
# spoken_languages        4635
# status                  4635
# tagline                 3890
# title                   4635
# vote_average            4635
# vote_count              4635
# movie_id                4635
# cast                    4635
# crew                    4635
# dtype: int64

# %%
merge_df_2 = merge_df_1[merge_df_1.genres != '[]']
merge_df_2.head(273)
# Out:
#         budget                                             genres  \
# 0    237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1    300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2    245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3    250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4    260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5    258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6    260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7    280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8    250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9    250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10   270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11   200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12   200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...

# %%
merge_df_3 = merge_df_2[merge_df_2.crew != '[]']
merge_df_3.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
merge_df_4 = merge_df_3[merge_df_3.cast != '[]']
merge_df_4.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
merge_new_index = merge_df_4.reset_index()
merge_new_index.head()
# Out:
#    index     budget                                             genres  \
# 0      0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1      1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2      2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3      3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4      4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# ...

# %%
# Clean the column genres ()
genre = []
for i in range(0,len(merge_new_index['genres'])):
    try:
        python_dict = json.loads(merge_new_index["genres"][i])
        genre.append(python_dict[0]['name'])
    except IndexError:
        genre.append(" ")

genres_df = pd.DataFrame(genre)
genres_df.head(2)
genres_df.count()
# Out:
# 0    4609
# dtype: int64

# %%
# Clean the column country
country =[]
for i in range(0,len(merge_new_index['production_countries'])):
    try:
        python_dict = json.loads(merge_new_index["production_countries"][i])
        country.append(python_dict[0]['name'])
    except IndexError:
        country.append(" ")
        
country_df = pd.DataFrame(country)
country_df.head(2)
country_df.count()
# Out:
# 0    4609
# dtype: int64

# %%
# Clean the column cast
cast1 =[]
for i in range(0,len(merge_new_index['cast'])):
    try:
        python_dict = json.loads(merge_new_index["cast"][i])
        cast1.append(python_dict[0]['name'])
    except IndexError:
        cast1.append(" ")
        
cast1_df = pd.DataFrame(cast1)
cast1_df.head(2)
cast1_df.count()
# Out:
# 0    4609
# dtype: int64

# %%
# Clean the column cast
cast2 =[]
for i in range(0,len(merge_new_index['cast'])):
    try:
        python_dict = json.loads(merge_new_index["cast"][i])
        cast2.append(python_dict[1]['name'])
    except IndexError:
        cast2.append(" ")

cast2_df = pd.DataFrame(cast2)
cast2_df.head(2)
cast2_df.count()
# Out:
# 0    4609
# dtype: int64

# %%
# Clean the column cast
cast3 =[]
for i in range(0,len(merge_new_index['cast'])):
    try:
        python_dict = json.loads(merge_new_index["cast"][i])
        cast3.append(python_dict[2]['name'])
    except IndexError:
        cast3.append(" ")
        
cast3_df = pd.DataFrame(cast3)
cast3_df.head(2)
cast3_df.count()
# Out:
# 0    4609
# dtype: int64

# %%
# Clean the column crew and take the information that we need (Director)
director=[]

for j in range(0,len(merge_new_index["crew"])):
    try:
        python_dict = json.loads(merge_new_index["crew"][j])
        directores = [x for x in python_dict if x["job"]=="Director"]
        if(len(directores)>0):
            director.append(directores[0]["name"])
        else:
            director.append("")
    except IndexError:
        director.append("")

director_df = pd.DataFrame(director)
director_df.head(2)
director_df.count()
# Out:
# 0    4609
# dtype: int64

# %%
# fill rows that don't have information with "NaN"
merge_new_index = merge_new_index.fillna(value="NaN")
merge_new_index.count()
# Out:
# index                   4609
# budget                  4609
# genres                  4609
# homepage                4609
# id                      4609
# keywords                4609
# original_language       4609
# original_title          4609
# overview                4609
# popularity              4609
# production_companies    4609
# production_countries    4609
# release_date            4609
# revenue                 4609
# runtime                 4609
# spoken_languages        4609
# status                  4609
# tagline                 4609
# title                   4609
# vote_average            4609
# vote_count              4609
# movie_id                4609
# cast                    4609
# crew                    4609
# dtype: int64

# %%
# Add the columns that we need for the analisis
merge_new_index["Genre"] = genres_df
# movie_data_new_index["Production Company"] = production_company_df
merge_new_index["Country"] = country_df
merge_new_index["Leading Role"] = cast1_df
merge_new_index["Supporting Role"] = cast2_df
merge_new_index["Supporting Role 2"] = cast3_df
merge_new_index["Director"] = director_df
# credits_data_df["Producer"] = producer_df
# credits_data_df["DP"] = dp_df
# credits_data_df["Writer"] = writer_df
# credits_data_df["Music Composer"] = music_composer_df
merge_new_index.count()
merge_new_index.head(20)
# Out:
#     index     budget                                             genres  \
# 0       0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1       1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2       2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3       3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4       4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5       5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6       6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7       7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8       8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9       9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10     10  270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11     11  200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# ...

# %%
# Delete the columns that we don't need
movie_data_needed = merge_new_index.drop(['genres','homepage', 'keywords', 'overview',
              'popularity', 'production_companies', 'status','tagline',
              'original_title', 'production_countries', 'spoken_languages','index','cast','crew','movie_id','id','vote_count'], axis = 1)
movie_data_needed.head(2)
#movie_data_needed.count()
# Out:
#       budget original_language release_date     revenue runtime  \
# 0  237000000                en   2009-12-10  2787965087     162
# 1  300000000                en   2007-05-19   961000000     169
#
#                                       title  vote_average      Genre  \
# 0                                    Avatar           7.2     Action
# 1  Pirates of the Caribbean: At World's End           6.9  Adventure
#
#                     Country     Leading Role Supporting Role  \
# 0  United States of America  Sam Worthington     Zoe Saldana
# 1  United States of America      Johnny Depp   Orlando Bloom
#
#   Supporting Role 2        Director
# 0  Sigourney Weaver   James Cameron
# 1   Keira Knightley  Gore Verbinski

# %%
# Rename columns
Renamed_Movie_Data_df = movie_data_needed.rename(columns = {'budget':'Budget',
                                            'original_language':'Language',
                                            'release_date':'Release_Date',
                                            'revenue':'Revenue',
                                            'runtime':'Runtime',
                                            'title':'Title',
                                            'vote_average':'Rating',
                                            'vote_count':'Vote_Count',
                                            'title':'Title',
                                            'Leading Role':'Leading_Role',
                                            })
Renamed_Movie_Data_df.count()
Renamed_Movie_Data_df.head(3000)
# Out:
#          Budget Language Release_Date     Revenue Runtime  \
# 0     237000000       en   2009-12-10  2787965087     162
# 1     300000000       en   2007-05-19   961000000     169
# 2     245000000       en   2015-10-26   880674609     148
# 3     250000000       en   2012-07-16  1084939099     165
# 4     260000000       en   2012-03-07   284139100     132
# 5     258000000       en   2007-05-01   890871626     139
# 6     260000000       en   2010-11-24   591794936     100
# 7     280000000       en   2015-04-22  1405403694     141
# 8     250000000       en   2009-07-07   933959197     153
# 9     250000000       en   2016-03-23   873260194     151
# 10    270000000       en   2006-06-28   391081192     154
# 11    200000000       en   2008-10-30   586090727     106
# 12    200000000       en   2006-06-20  1065659812     151
# 13    255000000       en   2013-07-03    89289910     149
# 14    225000000       en   2013-06-12   662845518     143
# ...

# %%
Renamed_Movie_Data_df.Director.fillna("NaN")
Renamed_Movie_Data_df.head(3)
# Out:
#       Budget Language Release_Date     Revenue Runtime  \
# 0  237000000       en   2009-12-10  2787965087     162
# 1  300000000       en   2007-05-19   961000000     169
# 2  245000000       en   2015-10-26   880674609     148
#
#                                       Title  Rating      Genre  \
# 0                                    Avatar     7.2     Action
# 1  Pirates of the Caribbean: At World's End     6.9  Adventure
# 2                                   Spectre     6.3     Action
#
#                     Country     Leading_Role  Supporting Role  \
# 0  United States of America  Sam Worthington      Zoe Saldana
# 1  United States of America      Johnny Depp    Orlando Bloom
# 2            United Kingdom     Daniel Craig  Christoph Waltz
#
#   Supporting Role 2        Director
# 0  Sigourney Weaver   James Cameron
# 1   Keira Knightley  Gore Verbinski
# 2       Léa Seydoux      Sam Mendes

# %%
# We count the unique values of genre
Renamed_Movie_Data_df.Genre.value_counts()
# Out:
# Drama              1155
# Comedy             1007
# Action              741
# Adventure           337
# Horror              286
# Crime               193
# Thriller            189
# Animation           120
# Fantasy             118
# Romance             103
# Science Fiction      94
# Documentary          59
# Family               53
# Mystery              40
# Music                34
# Western              27
# History              25
# War                  23
# TV Movie              4
# Foreign               1
# Name: Genre, dtype: int64

# %%
Movie_list = Renamed_Movie_Data_df.to_dict()
Movie_list = {key: str(value) for (key, value) in Movie_list.items()}
Movie_list
# Out:
# {'Budget': '{0: 237000000, 1: 300000000, 2: 245000000, 3: 250000000, 4: 260000000, 5: 258000000, 6: 260000000, 7: 280000000, 8: 250000000, 9: 250000000, 10: 270000000, 11: 200000000, 12: 200000000, 13: 255000000, 14: 225000000, 15: 225000000, 16: 220000000, 17: 380000000, 18: 225000000, 19: 250000000, 20: 215000000, 21: 200000000, 22: 250000000, 23: 180000000, 24: 207000000, 25: 200000000, 26: 250000000, 27: 209000000, 28: 150000000, 29: 200000000, 30: 200000000, 31: 200000000, 32: 200000000, 33: 210000000, 34: 200000000, 35: 150000000, 36: 210000000, 37: 200000000, 38: 200000000, 39: 170000000, 40: 200000000, 41: 200000000, 42: 200000000, 43: 200000000, 44: 190000000, 45: 200000000, 46: 250000000, 47: 190000000, 48: 195000000, 49: 105000000, 50: 150000000, 51: 180000000, 52: 195000000, 53: 185000000, 54: 175000000, 55: 185000000, 56: 185000000, 57: 180000000, 58: 140000000, 59: 200000000, 60: 200000000, 61: 176000003, 62: 180000000, 63: 180000000, 64: 178000000, 65: 185000000, 66: 1
# ...

# %%
#Movie_list

# %%
#print(len(Movie_list))
#print(len(Renamed_Movie_Data_df))
# Out:
# 14
# 4609

# %%
d = Renamed_Movie_Data_df.iloc[0].to_dict()
d.items()
# Out:
# dict_items([('Budget', 237000000), ('Language', 'en'), ('Release_Date', '2009-12-10'), ('Revenue', 2787965087), ('Runtime', 162.0), ('Title', 'Avatar'), ('Rating', 7.2), ('Genre', 'Action'), ('Country', 'United States of America'), ('Leading_Role', 'Sam Worthington'), ('Supporting Role', 'Zoe Saldana'), ('Supporting Role 2', 'Sigourney Weaver'), ('Director', 'James Cameron')])

# %% [markdown]
# # Connection to Databaes

# %% [raw]
# #String connection
# conn = "mongodb://localhost:27017"
# #Creation of Mongo Client
# client = pymongo.MongoClient(conn)
# #Conection to the DataBase
# db = client.moviesProject_DB
# #Drop the content if any
# db.moviesProject.drop()
#
# #document = Movie_list
# #print(documento)
#
# #db.moviesProject.insert_many([document])
# #mongoImp = db.moviesProject.insert_one([document])
#
# for x in range(0, len(Renamed_Movie_Data_df)):
#     document = Renamed_Movie_Data_df.iloc[x].to_dict()
#     document = {x: str(y) for x,y in document.items()}
#     db.moviesProject.insert_one(document)
